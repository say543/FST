# %%
import azureml.core
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %%
from azureml.core import Workspace



#old account in blob
subscription_id = "ddb33dc4-889c-4fa1-90ce-482d793d6480"
resource_group = "DevExp"
workspace_name = "DevExperimentation"






try:
    #print('1')
    ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
    #print('2')
    ws.write_config()
    print('Library configuration succeeded')
    print(ws.get_details()['id'])

    print('https://ms.portal.azure.com/#@microsoft.onmicrosoft.com/resource' + ws.get_details()['id'])
except:
    print('Workspace not found')
# Out:
# Library configuration succeeded
# /subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation
# https://ms.portal.azure.com/#@microsoft.onmicrosoft.com/resource/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation

# %%
#resource group in email inference
{
    "subscription_id": "58f08321-00aa-4ada-bd53-421ecd063782",
    "resource_group": "Compliant_LU",
    "workspace_name": "Teams_ws"
}
# Out:
# {'subscription_id': '58f08321-00aa-4ada-bd53-421ecd063782',
#  'resource_group': 'Compliant_LU',
#  'workspace_name': 'Teams_ws'}

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

#old gpu  8 nodes
#cluster_name = "P100-DualGPU"

# seems ok for 8 node
#cluster_name = "P100-QuadGPU"

# only 4 nodes 
cluster_name = "V100-QuadGPU"


# only 1 gpu 6 cores 
#cluster_name = "aml-compute"


try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
# Out:
# Found existing compute target.

# %%
ds = ws.get_default_datastore()

# %%
from azureml.core import Datastore
ds = Datastore.get(ws, 'chiecha_datastore')

# %%
#$AZUREML_DATAREFERENCE_e2b58eeb943a48968b3f9e7c5c7a9925
#reference can be used in python module(?? not sure, check in the future) 

#upload local model
##model_path_on_datastore = 'Teams_slot_model' #cased model,vocab is too small? Do not have frequent word like common
##ds_model = ds.path(model_path_on_datastore)
##ds.upload(src_dir=r'D:\dl_repo\Tagging_data\bert-base-English-cased-pytorch',
##          target_path= model_path_on_datastore,
##          overwrite=False,
##          show_progress=True)
##print(ds_model.as_mount())

#upload unsupervised local model
##model_path_on_datastore = 'Communication_slot_model_unsupervised' #cased model,vocab is too small? Do not have frequent word like common
##ds_model_unsupervised = ds.path(model_path_on_datastore)
##ds.upload(src_dir=r'D:\dl_repo\Data_model\Communication_unsupervised',
##          target_path= model_path_on_datastore,
##          overwrite=False,
##          show_progress=True)
##print(ds_model_unsupervised.as_mount())

#upload local data set
##path_on_datastore = 'datasets/Teams_communication'
##ds_data_communication = ds.path(path_on_datastore)
##ds.upload(src_dir=r'D:\dl_repo\Data_model\Communication_data',
##          target_path= path_on_datastore,
##          overwrite=False,
##          show_progress=True)

# files training data source
#path_on_datastore = 'resource/Data'
#ds_data_files = ds.path(path_on_datastore)
#ds.upload(src_dir=r'E:\fileAnswer_data_synthesis\CMF_training\resource\Data',
#          target_path= path_on_datastore,
#          overwrite=False,
#          show_progress=True)

# git data source for normal domain training
#path_on_datastore = 'resource/Data'
#ds_data_files = ds.path(path_on_datastore)

#ds.upload(src_dir=r'E:\CoreScienceDataStaging\datasources\Files\resource\Data',
#          target_path= path_on_datastore,
#          overwrite=False,
#          show_progress=True)


# local data source for normal domain training

path_on_datastore = './azureml_data'
ds_data_files = ds.path(path_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\azureml_data',
          target_path= path_on_datastore,
          overwrite=True,
          show_progress=True)


# 


# training script

training_script_on_datastore = './training_script'
ds_data_files = ds.path(training_script_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\training_script',
          target_path= training_script_on_datastore,
          overwrite=True,
          show_progress=True)



#TNLR v3 model
'''
TNLR_on_datastore = './TNLR'
ds_data_files = ds.path(TNLR_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\TNLR',
          target_path= TNLR_on_datastore,
          overwrite=True,
          show_progress=True)
'''

'''
#distill TNLR minilm model
TNLR_minilm_on_datastore = './TNLR_minilm'
ds_data_files = ds.path(TNLR_minilm_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\TNLR_minilm',
          target_path= TNLR_minilm_on_datastore,
          overwrite=True,
          show_progress=True)
'''
'''
#distill TNLR minilm six layer
TNLR_minilm_sixlayer_on_datastore = './TNLR_minilm_sixlayer'
ds_data_files = ds.path(TNLR_minilm_sixlayer_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\TNLR_minilm_sixlayer',
          target_path= TNLR_minilm_sixlayer_on_datastore,
          overwrite=True,
          show_progress=True)
'''

'''
#distill TNLR minilm tiny
TNLR_minilm_tiny_on_datastore = './TNLR_minilm_tiny'
ds_data_files = ds.path(TNLR_minilm_tiny_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\TNLR_minilm_tiny',
          target_path= TNLR_minilm_tiny_on_datastore,
          overwrite=True,
          show_progress=True)
'''


#distill BERT minilm model 12 layers
BERT_minilm_on_datastore = './BERT_minilm'
ds_data_files = ds.path(BERT_minilm_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\BERT_minilm',
          target_path= BERT_minilm_on_datastore,
          overwrite=True,
          show_progress=True)
# Out:
# Uploading an estimated of 77 files
# Uploading E:\azure_ml_notebook\azureml_data\atis_test_problematic_queires.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_test_problematic_queires.tsv, 1 files out of an estimated total of 77
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_single.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_single.tsv, 2 files out of an estimated total of 77
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_ten.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_ten.tsv, 3 files out of an estimated total of 77
# Uploading E:\azure_ml_notebook\azureml_data\filter_query_for_domain.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\filter_query_for_domain.tsv, 4 files out of an estimated total of 77
# Uploading E:\azure_ml_notebook\azureml_data\atis_train_ten.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_train_ten.tsv, 5 files out of an estimated total of 77
# ...

# %%
# minic and create an domain training experiemnt
from azureml.core import Experiment

# test different experiment name
experiment_name = 'MDM_joint_intent_slot_classification_using_TNLRv3' 
experiment = Experiment(ws, name=experiment_name)

# %% [markdown]
# ## Create a PyTorch estimator
# The AML SDK's PyTorch estimator enables you to easily submit PyTorch training jobs for both single-node and distributed runs. For more information on the PyTorch estimator, refer here. The following code will define a single-node PyTorch job.

# %%
##BATCH AI
from azureml.train.dnn import PyTorch



### for debug if data is reable
from azureml.core import Dataset

training_datastore_path = [(ds, './azureml_data/MDM_TrainSet_01202021v1_updated_04142021v1.tsv')]
#training_datastore_path = [(ds, './azureml_data/MDM_TrainSet_01202021v1_updated_04132021v1.tsv')]
#training_datastore_path = [(ds, './azureml_data/MDM_TrainSet_01202021v1.tsv')]
#training_datastore_path = [(ds, './azureml_data/MDM_TrainSet_small_01202021v1.tsv')]


training_dataset_obj = Dataset.File.from_files(path=training_datastore_path)

training_dataset_name = 'training_non_contexual_slot_data_set'
training_dataset_description = 'training_non_contexual_slot_data_set description'


training_dataset = training_dataset_obj.register(workspace=ws, name=training_dataset_name, description=training_dataset_description, create_new_version=True)


# augmented data test 
augmented_datastore_path = [(ds, './azureml_data/open_ppt_augmentation_04142021v1.tsv')]
#augmented_datastore_path = [(ds, './azureml_data/open_ppt_augmentation.tsv')]

augmented_dataset_obj = Dataset.File.from_files(path=augmented_datastore_path)

augmented_dataset_name = 'augmented_non_contexual_slot_data_set'
augmented_dataset_description = 'augmented_non_contexual_slot_data_set description'


augmented_dataset = augmented_dataset_obj.register(workspace=ws, name=augmented_dataset_name, description=augmented_dataset_description, create_new_version=True)


# tokenizer enforcement set
tokenizer_enforcement_datastore_path = [(ds, './azureml_data/tokenizer_enforcement_query.tsv')]

tokenizer_enforcement_dataset_obj = Dataset.File.from_files(path=tokenizer_enforcement_datastore_path)

tokenizer_enforcement_dataset_name = 'tokenizer_enforcement_non_contexual_slot_data_set'
tokenizer_enforcement_dataset_description = 'tokenizer_enforcement_non_contexual_slot_data_set description'


tokenizer_enforcement_dataset = tokenizer_enforcement_dataset_obj.register(workspace=ws, name=tokenizer_enforcement_dataset_name, description=tokenizer_enforcement_dataset_description, create_new_version=True)


#TNLR model
TNLRv3_path = [(ds, './TNLR/tnlrv3-base.pt')]

TNLRv3_obj = Dataset.File.from_files(path=TNLRv3_path)

TNLRv3_name = 'TNLRv3_pretrained_model'
TNLRv3_description = 'TNLRv3_pretrained_model description'

TNLRv3_model = TNLRv3_obj.register(workspace=ws, name=TNLRv3_name, description=TNLRv3_description, create_new_version=True)


#distill TNLR_minilm model
TNLR_minilm_path = [(ds, './TNLR_minilm/pytorch_model.bin')]

TNLR_minilm_obj = Dataset.File.from_files(path=TNLR_minilm_path)

TNLR_minilm_name = 'TNLR_minilm_name_pretrained_model'
TNLR_minilm_description = 'TNLR_minilm_pretrained_model description'

TNLR_minilm_model = TNLR_minilm_obj.register(workspace=ws, name=TNLR_minilm_name, description=TNLR_minilm_description, create_new_version=True)


TNLR_minilm_config_path = [(ds, './TNLR_minilm/config.json')]

TNLR_minilm_config_obj = Dataset.File.from_files(path=TNLR_minilm_config_path)

TNLR_minilm_config_name = 'TNLR_minilm_config_name_pretrained_model'
TNLR_minilm_config_description = 'TNLR_minilm_config_pretrained_model description'

TNLR_minilm_config_model = TNLR_minilm_config_obj.register(workspace=ws, name=TNLR_minilm_config_name, description=TNLR_minilm_config_description, create_new_version=True)

# distill TNLR_minilm_sixlayer
TNLR_minilm_sixlayer_path = [(ds, './TNLR_minilm_sixlayer/pytorch_model.bin')]

TNLR_minilm_sixlayer_obj = Dataset.File.from_files(path=TNLR_minilm_sixlayer_path)

TNLR_minilm_sixlayer_name = 'TNLR_minilm_sixlayer_name_pretrained_model'
TNLR_minilm_sixlayer_description = 'TNLR_minilm_sixlayer_pretrained_model description'

TNLR_minilm_sixlayer_model = TNLR_minilm_sixlayer_obj.register(workspace=ws, name=TNLR_minilm_sixlayer_name, description=TNLR_minilm_sixlayer_description, create_new_version=True)

TNLR_minilm_sixlayer_config_path = [(ds, './TNLR_minilm_sixlayer/config.json')]

TNLR_minilm_sixlayer_config_obj = Dataset.File.from_files(path=TNLR_minilm_sixlayer_config_path)

TNLR_minilm_sixlayer_config_name = 'TNLR_minilm_sixlayer_config_name_pretrained_model'
TNLR_minilm_sixlayer_config_description = 'TNLR_minilm_sixlayer_config_pretrained_model description'

TNLR_minilm_sixlayer_config_model = TNLR_minilm_sixlayer_config_obj.register(workspace=ws, name=TNLR_minilm_sixlayer_config_name, description=TNLR_minilm_sixlayer_config_description, create_new_version=True)



# distill TNLR_minilm_tiny
TNLR_minilm_tiny_path = [(ds, './TNLR_minilm_tiny/pytorch_model.bin')]

TNLR_minilm_tiny_obj = Dataset.File.from_files(path=TNLR_minilm_tiny_path)

TNLR_minilm_tiny_name = 'TNLR_minilm_tiny_name_pretrained_model'
TNLR_minilm_tiny_description = 'TNLR_minilm_tiny_pretrained_model description'

TNLR_minilm_tiny_model = TNLR_minilm_tiny_obj.register(workspace=ws, name=TNLR_minilm_tiny_name, description=TNLR_minilm_tiny_description, create_new_version=True)

TNLR_minilm_tiny_config_path = [(ds, './TNLR_minilm_tiny/config.json')]

TNLR_minilm_tiny_config_obj = Dataset.File.from_files(path=TNLR_minilm_tiny_config_path)

TNLR_minilm_tiny_config_name = 'TNLR_minilm_tiny_config_name_pretrained_model'
TNLR_minilm_tiny_config_description = 'TNLR_minilm_tiny_config_pretrained_model description'

TNLR_minilm_tiny_config_model = TNLR_minilm_tiny_config_obj.register(workspace=ws, name=TNLR_minilm_tiny_config_name, description=TNLR_minilm_tiny_config_description, create_new_version=True)


#distill BERT_minilm model
BERT_minilm_path = [(ds, './BERT_minilm/pytorch_model.bin')]

BERT_minilm_obj = Dataset.File.from_files(path=BERT_minilm_path)

BERT_minilm_name = 'BERT_minilm_name_pretrained_model'
BERT_minilm_description = 'BERT_minilm_pretrained_model description'

BERT_minilm_model = BERT_minilm_obj.register(workspace=ws, name=BERT_minilm_name, description=BERT_minilm_description, create_new_version=True)


BERT_minilm_config_path = [(ds, './BERT_minilm/config.json')]

BERT_minilm_config_obj = Dataset.File.from_files(path=BERT_minilm_config_path)

BERT_minilm_config_name = 'BERT_minilm_config_name_pretrained_model'
BERT_minilm_config_description = 'BERT_minilm_config_pretrained_model description'

BERT_minilm_config_model = BERT_minilm_config_obj.register(workspace=ws, name=BERT_minilm_config_name, description=BERT_minilm_config_description, create_new_version=True)


# for debug new format
import pandas as pd
file_name = training_dataset.download()[0]
df = pd.read_csv(file_name, sep='\t', encoding="utf-8")
print(df.head())





from azureml.core.runconfig import MpiConfiguration
from azureml.train.hyperdrive import GridParameterSampling
from azureml.train.hyperdrive import HyperDriveConfig
from azureml.train.hyperdrive import PrimaryMetricGoal
from azureml.train.hyperdrive.parameter_expressions import choice


script_folder = './training_script'



# new dataset name
script_params = {
    #'--dataset_name': 'training_data_set'
    '--dataset_name': 'training_non_contexual_slot_data_set',
    #augment dataset name
    '--augment_dataset_name': 'augmented_non_contexual_slot_data_set',
    #  tokenizer enforcement dataset
    #'--tokenizer_enforcement_dataset_name' :                           'tokenizer_enforcement_non_contexual_slot_data_set',
    # TNLV v3
    '--TNLR_model_bin': 'TNLRv3_model',
    # TNLR_minilm_model
    '--TNLR_minilm_model_bin': 'TNLR_minilm_name_pretrained_model',
    '--TNLR_minilm_model_config': 'TNLR_minilm_config_name_pretrained_model',
    #--TNLR_minilm_sixlayer_model
    '--TNLR_minilm_sixlayer_model_bin': 'TNLR_minilm_sixlayer_name_pretrained_model',
    '--TNLR_minilm_sixlayer_model_config': 'TNLR_minilm_sixlayer_config_name_pretrained_model',
    #--TNLR_minilm_tiny_model
    '--TNLR_minilm_tiny_model_bin': 'TNLR_minilm_tiny_name_pretrained_model',
    '--TNLR_minilm_tiny_model_config': 'TNLR_minilm_tiny_config_name_pretrained_model',
    # BERT_minilm_model
    '--BERT_minilm_model_bin': 'BERT_minilm_name_pretrained_model',
    '--BERT_minilm_model_config': 'BERT_minilm_config_name_pretrained_model',
    # configure for different model
    #'--pretrain_model': 'distilbert-base-uncased'
    #'--pretrain_model': 'bert-base-uncased'
    #'--pretrain_model': 'distilTNLR-base-uncased'
    #'--pretrain_model': 'distilTNLR-base-uncased-sixlayer'
    #'--pretrain_model': 'distilTNLR-base-uncased-tiny'
    # not sure whether this is the same huggingface or ont
    '--pretrain_model': 'distilbert-base-uncased-microsoft'
}



# deprecated estimator

estimator = PyTorch(source_directory = script_folder,
                    compute_target = compute_target,
                    entry_script = 'MDM_train_horovod_joint_intent_slot_TNLR.py',
                    script_params = script_params,
                    use_gpu = True,
                    #node_count=8,
                    # for 
                    #node_count=6,
                    #node_count=4,
                    #node_count=3,
                    #node_count=2,
                    node_count=1,
                    process_count_per_node=1,
                    distributed_training=MpiConfiguration(),
                    # setup transformers package number
                    #pip_packages = ['sklearn', 'joblib', 'transformers', 'azureml-dataprep[fuse,pandas]'])
                    ### default setting
                    #pip_packages = ['sklearn', 'joblib', 'transformers==4.1.1', 'azureml-dataprep[fuse,pandas]', 'seqeval'])
                    ### torch == 1.7.1 same as my local verion but horovod will fail
                    #pip_packages = ['sklearn', 'joblib', 'transformers==4.1.1', 'torch==1.7.1','torchvision==0.8.2', 'torchaudio==0.7.2',azureml-dataprep[fuse,pandas]', 'seqeval'])
                    ### torch == 1.6.0 setting
                    pip_packages = ['sklearn', 'joblib', 'transformers==4.1.1', 'torch==1.6.0','torchvision==0.7.0','horovod==0.19.5','azureml-dataprep[fuse,pandas]', 'seqeval'])




#ve
param_sampling = GridParameterSampling({
    'batch_size': choice(32),
    # originla learning rate
    #'learning_rate': choice(1e-5),
    # change to bigger learning rate
    'learning_rate': choice(5e-5),
    # combined tow at the same time
    #'learning_rate': choice(5e-5, 1e-5),
    'adam_epsilon': choice(1e-8),
    'seed_val': choice(111),
    # add epoch parameter
    #'num_epochs': choice(1)})
    #'num_epochs': choice(2)})
    #'num_epochs': choice(5)})
    #'num_epochs': choice(25)})
    'num_epochs': choice(10)})
    #'num_epochs': choice(10)})
    #'num_epochs': choice(5,10)})
    #'num_epochs': choice(5,10,15)})
    #'num_epochs': choice(15,20,25)})
    #'num_epochs': choice(5,10,15,20,25)})



#horovod
#https://docs.microsoft.com/en-us/azure/machine-learning/how-to-train-pytorch
hyperdrive_run_config = HyperDriveConfig(estimator = estimator,
                                         hyperparameter_sampling = param_sampling,
                                         policy = None,
                                         primary_metric_name = 'validation loss',
                                         primary_metric_goal = PrimaryMetricGoal.MINIMIZE,
                                         # increase to 3 to see different validation through graph
                                         # ? but graph still only outputs one point
                                         #max_total_runs = 1,
                                         max_total_runs = 5,
                                         max_concurrent_runs = 1)


#hyperdrive_run = exp.submit(hyperdrive_run_config)
hyperdrive_run = experiment.submit(hyperdrive_run_config)
# show detail
from azureml.widgets import RunDetails
RunDetails(hyperdrive_run).show()


# this is to show metric so comment it at first

hyperdrive_run.wait_for_completion(show_output = False)

children = list(hyperdrive_run.get_children())
metricslist = {}
i = 0

for single_run in children:
    results = {k: v for k, v in single_run.get_metrics().items() if isinstance(v, float)}
    parameters = single_run.get_details()['runDefinition']['arguments']
    try:
        results['batch_size'] = parameters[3]
        results['learning_rate'] = parameters[5]
        results['adam_epsilon'] = parameters[7]
        results['num_epochs'] = parameters[9]
        metricslist[i] = results
        i += 1
    except:
        pass

rundata = pd.DataFrame(metricslist).sort_index(1).T.sort_values(by = ['validation loss'], ascending = True)
rundata
# Out:
# C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (2,8,9,11,12,13,14,18,23,25,27,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# framework_version is not specified, defaulting to version 1.4.
# You have specified to install packages in your run. Note that you have overridden Azure ML's installation of the following packages: ['torch', 'torchvision', 'horovod']. We cannot guarantee image build will succeed.
# WARNING:root:If 'script' has been provided here and a script file name has been specified in 'run_config', 'script' provided in ScriptRunConfig initialization will take precedence.
# WARNING:root:If 'arguments' has been provided here and arguments have been specified in 'run_config', 'arguments' provided in ScriptRunConfig initialization will take precedence.
# ...
