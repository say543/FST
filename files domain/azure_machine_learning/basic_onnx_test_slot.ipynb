# %% [markdown]
# #remove torchscript
# # change to distillation bert
# #output to onnx
# # gpu version
# # https://github.com/huggingface/transformers/issues/227
# #https://huggingface.co/transformers/serialization.html

# %%
from transformers import DistilBertTokenizer,DistilBertTokenizerFast
from transformers import DistilBertForTokenClassification, AdamW, DistilBertConfig
from transformers import BatchEncoding
from tokenizers import Encoding
import torch


# read label
from typing_extensions import TypedDict
from typing import List,Any
IntList = List[int] # A list of token_ids
IntListList = List[IntList] # A List of List of token_ids, e.g. a Batch


import itertools
class LabelSet:
    def __init__(self, labels: List[str]):
        self.labels_to_id = {}
        self.ids_to_label = {}

        self.labels_to_id["o"] = 0
        self.ids_to_label[0] = "o"
        num = 1
        for label in labels:
            if label == "o":
                print("skip:{}".format(label))
                continue
            self.labels_to_id[label] = num
            self.ids_to_label[num] = label
            num = num +1 


    def get_aligned_label_ids_from_aligned_label(self, aligned_labels):
        return list(map(self.labels_to_id.get, aligned_labels))

    def get_untagged_id(self):
        return self.labels_to_id["o"]

    def get_labels(self):
        return self.labels_to_id

slots = ["O", 
    "file_name", 
    "file_type", 
    "data_source", 
    "contact_name", 
    "to_contact_name",
    "file_keyword",
    "date",
    "time",
    "meeting_starttime",
    "file_action",
    "file_action_context",
    "position_ref",
    "order_ref",
    "file_recency",
    "sharetarget_type",
    "sharetarget_name",
    "file_folder",
    "data_source_name",
    "data_source_type",
    "attachment"]

# map all slots to lower case
slots_label_set = LabelSet(labels=map(str.lower,slots))



#enc = BertTokenizer.from_pretrained("bert-base-uncased")
fast_tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased') # Load a pre-trained tokenizer

# Tokenizing input text
#text = "[CLS] a visually stunning rumination on love"
#text = "[CLS] a visually stunning rumination on love [SEP]"
text = "a visually stunning rumination on love"
fast_tokenized_batch : BatchEncoding = fast_tokenizer(text)
fast_tokenized_text :Encoding  =fast_tokenized_batch[0]
fast_tokenized_text_tokens_copy = fast_tokenized_text.tokens


# for deubg
fast_tokenized_text_old = fast_tokenizer.tokenize(text)
print("fast token ouput version 1: {}".format(fast_tokenized_text_old))
print("fast token ouput version 2 being used here: {}".format(fast_tokenized_text_tokens_copy))

# Masking one of the input tokens
# ? in yue's tutria; for bert it does not have [mask] for replacement. so this migt be optional
# check in the future
masked_index = 3
fast_tokenized_text_tokens_copy[masked_index] = '[MASK]'
indexed_tokens = fast_tokenizer.convert_tokens_to_ids(fast_tokenized_text_tokens_copy)

# for debug 
print("fast token ouput version 2 being used here after replace: {}".format(fast_tokenized_text_tokens_copy))

print("indexed_tokens: {}".format(indexed_tokens))
segments_ids = [0]

# Creating a dummy input
# but you need to move tensors to GPU
#https://github.com/huggingface/transformers/issues/227
# discuss convertion
#https://discuss.pytorch.org/t/best-way-to-convert-a-list-to-a-tensor/59949/2
#torch.tensor
#tokens_tensor = torch.tensor([indexed_tokens])
#segments_tensors = torch.tensor([segments_ids])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("create input for device: {}".format(device))
tokens_tensor = torch.tensor([indexed_tokens]).to(device)
segments_tensors = torch.tensor([segments_ids]).to(device)
dummy_input = tokens_tensor


# for debug
print("tokens_tensor shape for chunk: {}".format(tokens_tensor[0].shape[0])) 
for token_tensor in tokens_tensor:
    print("token_tensor shape for chunk: {}".format(token_tensor.shape[0]))


# for deubg
# 14 tokens for output
print("tokens_tensor shape: {}".format(tokens_tensor.shape))
print("segments_tensor shape: {}".format(segments_tensors.shape))

print("tokens_tensor: {}".format(tokens_tensor))
print("segments_tensor: {}".format(segments_tensors))


# Initializing the model with the torchscript flag
# Flag set to True even though it is not necessary as this model does not have an LM Head.
#config = BertConfig(vocab_size_or_config_json_file=32000, hidden_size=768,
#    num_hidden_layers=12, num_attention_heads=12, intermediate_size=3072, torchscript=True)

# Instantiating the model
#model = BertModel(config)

# The model needs to be in evaluation mode
#model.eval()

# If you are instantiating the model with `from_pretrained` you can also easily set the TorchScript flag
#model = BertModel.from_pretrained("bert-base-uncased", torchscript=True)
num_labels = len(set(slots_label_set.get_labels()))
model = DistilBertForTokenClassification.from_pretrained('distilbert-base-uncased', num_labels=num_labels,
                                                            output_attentions=False, output_hidden_states=False)




torch.onnx.export(model=model,
    args=(dummy_input),
    f='traced_distill_bert.onnx.bin',
    input_names = ["input_ids"],
    verbose=True,
    output_names = ["logits"],
    do_constant_folding = True,
    opset_version=11,
    dynamic_axes = {'input_ids': {1: '?'}, 'logits': {1: '?'}}
    )


# if want to want to download, uncomment it 
#torch.jit.save(traced_model, "traced_distill_bert.pt")
# Out:
# skip:o
# fast token ouput version 1: ['a', 'visually', 'stunning', 'rum', '##ination', 'on', 'love']
# fast token ouput version 2 being used here: ['[CLS]', 'a', 'visually', 'stunning', 'rum', '##ination', 'on', 'love', '[SEP]']
# fast token ouput version 2 being used here after replace: ['[CLS]', 'a', 'visually', '[MASK]', 'rum', '##ination', 'on', 'love', '[SEP]']
# indexed_tokens: [101, 1037, 17453, 103, 19379, 12758, 2006, 2293, 102]
# create input for device: cpu
# tokens_tensor shape for chunk: 9
# token_tensor shape for chunk: 9
# tokens_tensor shape: torch.Size([1, 9])
# segments_tensor shape: torch.Size([1, 1])
# tokens_tensor: tensor([[  101,  1037, 17453,   103, 19379, 12758,  2006,  2293,   102]])
# segments_tensor: tensor([[0]])
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForTokenClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# graph(%input_ids : Long(1:9, 9:1, requires_grad=0, device=cpu),
#       %distilbert.embeddings.word_embeddings.weight : Float(30522:768, 768:1, requires_grad=1, device=cpu),
#       %distilbert.embeddings.position_embeddings.weight : Float(512:768, 768:1, requires_grad=1, device=cpu),
#       %distilbert.embeddings.LayerNorm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.embeddings.LayerNorm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.attention.q_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.attention.k_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.attention.v_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.attention.out_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.sa_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.sa_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.ffn.lin1.bias : Float(3072:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.ffn.lin2.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.output_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.0.output_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.attention.q_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.attention.k_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.attention.v_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.attention.out_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.sa_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.sa_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.ffn.lin1.bias : Float(3072:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.ffn.lin2.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.output_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.1.output_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.attention.q_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.attention.k_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.attention.v_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.attention.out_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.sa_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.sa_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.ffn.lin1.bias : Float(3072:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.ffn.lin2.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.output_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.2.output_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.attention.q_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.attention.k_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.attention.v_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.attention.out_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.sa_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.sa_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.ffn.lin1.bias : Float(3072:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.ffn.lin2.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.output_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.3.output_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.attention.q_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.attention.k_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.attention.v_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.attention.out_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.sa_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.sa_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.ffn.lin1.bias : Float(3072:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.ffn.lin2.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.output_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.4.output_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.attention.q_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.attention.k_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.attention.v_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.attention.out_lin.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.sa_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.sa_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.ffn.lin1.bias : Float(3072:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.ffn.lin2.bias : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.output_layer_norm.weight : Float(768:1, requires_grad=1, device=cpu),
#       %distilbert.transformer.layer.5.output_layer_norm.bias : Float(768:1, requires_grad=1, device=cpu),
#       %classifier.bias : Float(21:1, requires_grad=1, device=cpu),
#       %850 : Float(requires_grad=0, device=cpu),
#       %851 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %852 : Long(1:1, requires_grad=0, device=cpu),
#       %853 : Long(1:1, requires_grad=0, device=cpu),
#       %854 : Long(1:1, requires_grad=0, device=cpu),
#       %855 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %856 : Long(1:1, requires_grad=0, device=cpu),
#       %857 : Long(1:1, requires_grad=0, device=cpu),
#       %858 : Long(1:1, requires_grad=0, device=cpu),
#       %859 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %860 : Long(1:1, requires_grad=0, device=cpu),
#       %861 : Long(1:1, requires_grad=0, device=cpu),
#       %862 : Long(1:1, requires_grad=0, device=cpu),
#       %863 : Long(1:1, requires_grad=0, device=cpu),
#       %864 : Long(1:1, requires_grad=0, device=cpu),
#       %865 : Long(1:1, requires_grad=0, device=cpu),
#       %866 : Long(1:1, requires_grad=0, device=cpu),
#       %867 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %868 : Float(requires_grad=0, device=cpu),
#       %869 : Float(768:1, 3072:768, requires_grad=0, device=cpu),
#       %870 : Float(3072:1, 768:3072, requires_grad=0, device=cpu),
#       %871 : Float(requires_grad=0, device=cpu),
#       %872 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %873 : Long(1:1, requires_grad=0, device=cpu),
#       %874 : Long(1:1, requires_grad=0, device=cpu),
#       %875 : Long(1:1, requires_grad=0, device=cpu),
#       %876 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %877 : Long(1:1, requires_grad=0, device=cpu),
#       %878 : Long(1:1, requires_grad=0, device=cpu),
#       %879 : Long(1:1, requires_grad=0, device=cpu),
#       %880 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %881 : Long(1:1, requires_grad=0, device=cpu),
#       %882 : Long(1:1, requires_grad=0, device=cpu),
#       %883 : Long(1:1, requires_grad=0, device=cpu),
#       %884 : Long(1:1, requires_grad=0, device=cpu),
#       %885 : Long(1:1, requires_grad=0, device=cpu),
#       %886 : Long(1:1, requires_grad=0, device=cpu),
#       %887 : Long(1:1, requires_grad=0, device=cpu),
#       %888 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %889 : Float(requires_grad=0, device=cpu),
#       %890 : Float(768:1, 3072:768, requires_grad=0, device=cpu),
#       %891 : Float(3072:1, 768:3072, requires_grad=0, device=cpu),
#       %892 : Float(requires_grad=0, device=cpu),
#       %893 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %894 : Long(1:1, requires_grad=0, device=cpu),
#       %895 : Long(1:1, requires_grad=0, device=cpu),
#       %896 : Long(1:1, requires_grad=0, device=cpu),
#       %897 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %898 : Long(1:1, requires_grad=0, device=cpu),
#       %899 : Long(1:1, requires_grad=0, device=cpu),
#       %900 : Long(1:1, requires_grad=0, device=cpu),
#       %901 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %902 : Long(1:1, requires_grad=0, device=cpu),
#       %903 : Long(1:1, requires_grad=0, device=cpu),
#       %904 : Long(1:1, requires_grad=0, device=cpu),
#       %905 : Long(1:1, requires_grad=0, device=cpu),
#       %906 : Long(1:1, requires_grad=0, device=cpu),
#       %907 : Long(1:1, requires_grad=0, device=cpu),
#       %908 : Long(1:1, requires_grad=0, device=cpu),
#       %909 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %910 : Float(requires_grad=0, device=cpu),
#       %911 : Float(768:1, 3072:768, requires_grad=0, device=cpu),
#       %912 : Float(3072:1, 768:3072, requires_grad=0, device=cpu),
#       %913 : Float(requires_grad=0, device=cpu),
#       %914 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %915 : Long(1:1, requires_grad=0, device=cpu),
#       %916 : Long(1:1, requires_grad=0, device=cpu),
#       %917 : Long(1:1, requires_grad=0, device=cpu),
#       %918 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %919 : Long(1:1, requires_grad=0, device=cpu),
#       %920 : Long(1:1, requires_grad=0, device=cpu),
#       %921 : Long(1:1, requires_grad=0, device=cpu),
#       %922 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %923 : Long(1:1, requires_grad=0, device=cpu),
#       %924 : Long(1:1, requires_grad=0, device=cpu),
#       %925 : Long(1:1, requires_grad=0, device=cpu),
#       %926 : Long(1:1, requires_grad=0, device=cpu),
#       %927 : Long(1:1, requires_grad=0, device=cpu),
#       %928 : Long(1:1, requires_grad=0, device=cpu),
#       %929 : Long(1:1, requires_grad=0, device=cpu),
#       %930 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %931 : Float(requires_grad=0, device=cpu),
#       %932 : Float(768:1, 3072:768, requires_grad=0, device=cpu),
#       %933 : Float(3072:1, 768:3072, requires_grad=0, device=cpu),
#       %934 : Float(requires_grad=0, device=cpu),
#       %935 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %936 : Long(1:1, requires_grad=0, device=cpu),
#       %937 : Long(1:1, requires_grad=0, device=cpu),
#       %938 : Long(1:1, requires_grad=0, device=cpu),
#       %939 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %940 : Long(1:1, requires_grad=0, device=cpu),
#       %941 : Long(1:1, requires_grad=0, device=cpu),
#       %942 : Long(1:1, requires_grad=0, device=cpu),
#       %943 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %944 : Long(1:1, requires_grad=0, device=cpu),
#       %945 : Long(1:1, requires_grad=0, device=cpu),
#       %946 : Long(1:1, requires_grad=0, device=cpu),
#       %947 : Long(1:1, requires_grad=0, device=cpu),
#       %948 : Long(1:1, requires_grad=0, device=cpu),
#       %949 : Long(1:1, requires_grad=0, device=cpu),
#       %950 : Long(1:1, requires_grad=0, device=cpu),
#       %951 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %952 : Float(requires_grad=0, device=cpu),
#       %953 : Float(768:1, 3072:768, requires_grad=0, device=cpu),
#       %954 : Float(3072:1, 768:3072, requires_grad=0, device=cpu),
#       %955 : Float(requires_grad=0, device=cpu),
#       %956 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %957 : Long(1:1, requires_grad=0, device=cpu),
#       %958 : Long(1:1, requires_grad=0, device=cpu),
#       %959 : Long(1:1, requires_grad=0, device=cpu),
#       %960 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %961 : Long(1:1, requires_grad=0, device=cpu),
#       %962 : Long(1:1, requires_grad=0, device=cpu),
#       %963 : Long(1:1, requires_grad=0, device=cpu),
#       %964 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %965 : Long(1:1, requires_grad=0, device=cpu),
#       %966 : Long(1:1, requires_grad=0, device=cpu),
#       %967 : Long(1:1, requires_grad=0, device=cpu),
#       %968 : Long(1:1, requires_grad=0, device=cpu),
#       %969 : Long(1:1, requires_grad=0, device=cpu),
#       %970 : Long(1:1, requires_grad=0, device=cpu),
#       %971 : Long(1:1, requires_grad=0, device=cpu),
#       %972 : Float(768:1, 768:768, requires_grad=0, device=cpu),
#       %973 : Float(requires_grad=0, device=cpu),
#       %974 : Float(768:1, 3072:768, requires_grad=0, device=cpu),
#       %975 : Float(3072:1, 768:3072, requires_grad=0, device=cpu),
#       %976 : Float(requires_grad=0, device=cpu),
#       %977 : Float(768:1, 21:768, requires_grad=0, device=cpu)):
#   %103 : Tensor = onnx::Shape(%input_ids)
#   %104 : Tensor = onnx::Constant[value={0}]()
#   %105 : Long(device=cpu) = onnx::Gather[axis=0](%103, %104) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:465:0
#   %106 : Tensor = onnx::Shape(%input_ids)
#   %107 : Tensor = onnx::Constant[value={1}]()
#   %108 : Long(device=cpu) = onnx::Gather[axis=0](%106, %107) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:465:0
#   %109 : Tensor = onnx::Unsqueeze[axes=[0]](%105)
#   %110 : Tensor = onnx::Unsqueeze[axes=[0]](%108)
#   %111 : Tensor = onnx::Concat[axis=0](%109, %110)
#   %112 : Float(1:9, 9:1, requires_grad=0, device=cpu) = onnx::ConstantOfShape[value={1}](%111) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:474:0
#   %113 : Tensor = onnx::Shape(%input_ids)
#   %114 : Tensor = onnx::Constant[value={1}]()
#   %115 : Long(device=cpu) = onnx::Gather[axis=0](%113, %114) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:103:0
#   %116 : Tensor = onnx::Cast[to=7](%115)
#   %117 : Tensor = onnx::Constant[value={0}]()
#   %118 : Tensor = onnx::Constant[value={1}]()
#   %119 : Long(9:1, requires_grad=0, device=cpu) = onnx::Range(%117, %116, %118) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:104:0
#   %120 : Long(1:9, 9:1, requires_grad=0, device=cpu) = onnx::Unsqueeze[axes=[0]](%119) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:105:0
#   %121 : Tensor = onnx::Shape(%input_ids)
#   %122 : Long(1:9, 9:1, requires_grad=0, device=cpu) = onnx::Expand(%120, %121) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:105:0
#   %123 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Gather(%distilbert.embeddings.word_embeddings.weight, %input_ids) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1852:0
#   %124 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Gather(%distilbert.embeddings.position_embeddings.weight, %122) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1852:0
#   %125 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%123, %124) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:110:0
#   %127 : Tensor = onnx::ReduceMean[axes=[-1]](%125)
#   %128 : FloatTensor = onnx::Sub(%125, %127)
#   %129 : Tensor = onnx::Cast[to=1](%128)
#   %131 : Tensor = onnx::Pow(%129, %850)
#   %132 : Tensor = onnx::ReduceMean[axes=[-1]](%131)
#   %133 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %134 : FloatTensor = onnx::Add(%132, %133)
#   %135 : Tensor = onnx::Sqrt(%134)
#   %136 : FloatTensor = onnx::Div(%128, %135)
#   %137 : FloatTensor = onnx::Mul(%136, %distilbert.embeddings.LayerNorm.weight)
#   %138 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%137, %distilbert.embeddings.LayerNorm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %139 : Tensor = onnx::Shape(%138)
#   %140 : Tensor = onnx::Constant[value={0}]()
#   %141 : Long(device=cpu) = onnx::Gather[axis=0](%139, %140) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:160:0
#   %142 : Tensor = onnx::Shape(%138)
#   %143 : Tensor = onnx::Constant[value={1}]()
#   %144 : Long(device=cpu) = onnx::Gather[axis=0](%142, %143) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:161:0
#   %146 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%138, %851) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %147 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%146, %distilbert.transformer.layer.0.attention.q_lin.bias)
#   %151 : Tensor = onnx::Unsqueeze[axes=[0]](%141)
#   %155 : Tensor = onnx::Concat[axis=0](%151, %852, %853, %854)
#   %156 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%147, %155) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %157 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%156) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %159 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%138, %855) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %160 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%159, %distilbert.transformer.layer.0.attention.k_lin.bias)
#   %164 : Tensor = onnx::Unsqueeze[axes=[0]](%141)
#   %168 : Tensor = onnx::Concat[axis=0](%164, %856, %857, %858)
#   %169 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%160, %168) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %171 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%138, %859) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %172 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%171, %distilbert.transformer.layer.0.attention.v_lin.bias)
#   %176 : Tensor = onnx::Unsqueeze[axes=[0]](%141)
#   %180 : Tensor = onnx::Concat[axis=0](%176, %860, %861, %862)
#   %181 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%172, %180) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %182 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%181) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %183 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={8}]()
#   %184 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Div(%157, %183)
#   %185 : Float(1:6912, 12:64, 64:1, 9:768, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 3, 1]](%169) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %186 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::MatMul(%184, %185) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %187 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %188 : Bool(1:9, 9:1, requires_grad=0, device=cpu) = onnx::Equal(%112, %187) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\tensor.py:27:0
#   %191 : Tensor = onnx::Unsqueeze[axes=[0]](%141)
#   %194 : Tensor = onnx::Unsqueeze[axes=[0]](%144)
#   %195 : Tensor = onnx::Concat[axis=0](%191, %863, %864, %194)
#   %196 : Bool(1:9, 1:9, 1:9, 9:1, requires_grad=0, device=cpu) = onnx::Reshape(%188, %195) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %197 : Tensor = onnx::Shape(%186)
#   %198 : Bool(1:9, 12:0, 9:0, 9:1, requires_grad=0, device=cpu) = onnx::Expand(%196, %197) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %199 : Tensor = onnx::Cast[to=9](%198)
#   %200 : Tensor = onnx::Constant[value={-inf}]()
#   %201 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Where(%199, %200, %186)
#   %202 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Softmax[axis=3](%201) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %203 : Float(1:6912, 12:576, 9:64, 64:1, requires_grad=1, device=cpu) = onnx::MatMul(%202, %182) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:193:0
#   %204 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%203) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %207 : Tensor = onnx::Unsqueeze[axes=[0]](%141)
#   %210 : Tensor = onnx::Concat[axis=0](%207, %865, %866)
#   %211 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Reshape(%204, %210) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %213 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%211, %867) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %214 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%213, %distilbert.transformer.layer.0.attention.out_lin.bias)
#   %215 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%214, %138) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:263:0
#   %217 : Tensor = onnx::ReduceMean[axes=[-1]](%215)
#   %218 : FloatTensor = onnx::Sub(%215, %217)
#   %219 : Tensor = onnx::Cast[to=1](%218)
#   %221 : Tensor = onnx::Pow(%219, %868)
#   %222 : Tensor = onnx::ReduceMean[axes=[-1]](%221)
#   %223 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %224 : FloatTensor = onnx::Add(%222, %223)
#   %225 : Tensor = onnx::Sqrt(%224)
#   %226 : FloatTensor = onnx::Div(%218, %225)
#   %227 : FloatTensor = onnx::Mul(%226, %distilbert.transformer.layer.0.sa_layer_norm.weight)
#   %228 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%227, %distilbert.transformer.layer.0.sa_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %230 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::MatMul(%228, %869) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %231 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Add(%230, %distilbert.transformer.layer.0.ffn.lin1.bias)
#   %232 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.41421}]()
#   %233 : FloatTensor = onnx::Div(%231, %232)
#   %234 : Tensor = onnx::Erf(%233)
#   %235 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %236 : FloatTensor = onnx::Add(%234, %235)
#   %237 : FloatTensor = onnx::Mul(%231, %236)
#   %238 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.5}]()
#   %239 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Mul(%237, %238) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1383:0
#   %241 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%239, %870) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %242 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%241, %distilbert.transformer.layer.0.ffn.lin2.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %243 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%242, %228) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:267:0
#   %245 : Tensor = onnx::ReduceMean[axes=[-1]](%243)
#   %246 : FloatTensor = onnx::Sub(%243, %245)
#   %247 : Tensor = onnx::Cast[to=1](%246)
#   %249 : Tensor = onnx::Pow(%247, %871)
#   %250 : Tensor = onnx::ReduceMean[axes=[-1]](%249)
#   %251 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %252 : FloatTensor = onnx::Add(%250, %251)
#   %253 : Tensor = onnx::Sqrt(%252)
#   %254 : FloatTensor = onnx::Div(%246, %253)
#   %255 : FloatTensor = onnx::Mul(%254, %distilbert.transformer.layer.0.output_layer_norm.weight)
#   %256 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%255, %distilbert.transformer.layer.0.output_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %257 : Tensor = onnx::Shape(%256)
#   %258 : Tensor = onnx::Constant[value={0}]()
#   %259 : Long(device=cpu) = onnx::Gather[axis=0](%257, %258) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:160:0
#   %260 : Tensor = onnx::Shape(%256)
#   %261 : Tensor = onnx::Constant[value={1}]()
#   %262 : Long(device=cpu) = onnx::Gather[axis=0](%260, %261) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:161:0
#   %264 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%256, %872) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %265 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%264, %distilbert.transformer.layer.1.attention.q_lin.bias)
#   %269 : Tensor = onnx::Unsqueeze[axes=[0]](%259)
#   %273 : Tensor = onnx::Concat[axis=0](%269, %873, %874, %875)
#   %274 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%265, %273) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %275 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%274) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %277 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%256, %876) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %278 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%277, %distilbert.transformer.layer.1.attention.k_lin.bias)
#   %282 : Tensor = onnx::Unsqueeze[axes=[0]](%259)
#   %286 : Tensor = onnx::Concat[axis=0](%282, %877, %878, %879)
#   %287 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%278, %286) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %289 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%256, %880) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %290 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%289, %distilbert.transformer.layer.1.attention.v_lin.bias)
#   %294 : Tensor = onnx::Unsqueeze[axes=[0]](%259)
#   %298 : Tensor = onnx::Concat[axis=0](%294, %881, %882, %883)
#   %299 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%290, %298) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %300 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%299) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %301 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={8}]()
#   %302 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Div(%275, %301)
#   %303 : Float(1:6912, 12:64, 64:1, 9:768, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 3, 1]](%287) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %304 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::MatMul(%302, %303) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %305 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %306 : Bool(1:9, 9:1, requires_grad=0, device=cpu) = onnx::Equal(%112, %305) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\tensor.py:27:0
#   %309 : Tensor = onnx::Unsqueeze[axes=[0]](%259)
#   %312 : Tensor = onnx::Unsqueeze[axes=[0]](%262)
#   %313 : Tensor = onnx::Concat[axis=0](%309, %884, %885, %312)
#   %314 : Bool(1:9, 1:9, 1:9, 9:1, requires_grad=0, device=cpu) = onnx::Reshape(%306, %313) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %315 : Tensor = onnx::Shape(%304)
#   %316 : Bool(1:9, 12:0, 9:0, 9:1, requires_grad=0, device=cpu) = onnx::Expand(%314, %315) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %317 : Tensor = onnx::Cast[to=9](%316)
#   %318 : Tensor = onnx::Constant[value={-inf}]()
#   %319 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Where(%317, %318, %304)
#   %320 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Softmax[axis=3](%319) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %321 : Float(1:6912, 12:576, 9:64, 64:1, requires_grad=1, device=cpu) = onnx::MatMul(%320, %300) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:193:0
#   %322 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%321) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %325 : Tensor = onnx::Unsqueeze[axes=[0]](%259)
#   %328 : Tensor = onnx::Concat[axis=0](%325, %886, %887)
#   %329 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Reshape(%322, %328) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %331 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%329, %888) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %332 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%331, %distilbert.transformer.layer.1.attention.out_lin.bias)
#   %333 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%332, %256) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:263:0
#   %335 : Tensor = onnx::ReduceMean[axes=[-1]](%333)
#   %336 : FloatTensor = onnx::Sub(%333, %335)
#   %337 : Tensor = onnx::Cast[to=1](%336)
#   %339 : Tensor = onnx::Pow(%337, %889)
#   %340 : Tensor = onnx::ReduceMean[axes=[-1]](%339)
#   %341 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %342 : FloatTensor = onnx::Add(%340, %341)
#   %343 : Tensor = onnx::Sqrt(%342)
#   %344 : FloatTensor = onnx::Div(%336, %343)
#   %345 : FloatTensor = onnx::Mul(%344, %distilbert.transformer.layer.1.sa_layer_norm.weight)
#   %346 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%345, %distilbert.transformer.layer.1.sa_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %348 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::MatMul(%346, %890) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %349 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Add(%348, %distilbert.transformer.layer.1.ffn.lin1.bias)
#   %350 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.41421}]()
#   %351 : FloatTensor = onnx::Div(%349, %350)
#   %352 : Tensor = onnx::Erf(%351)
#   %353 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %354 : FloatTensor = onnx::Add(%352, %353)
#   %355 : FloatTensor = onnx::Mul(%349, %354)
#   %356 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.5}]()
#   %357 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Mul(%355, %356) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1383:0
#   %359 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%357, %891) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %360 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%359, %distilbert.transformer.layer.1.ffn.lin2.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %361 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%360, %346) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:267:0
#   %363 : Tensor = onnx::ReduceMean[axes=[-1]](%361)
#   %364 : FloatTensor = onnx::Sub(%361, %363)
#   %365 : Tensor = onnx::Cast[to=1](%364)
#   %367 : Tensor = onnx::Pow(%365, %892)
#   %368 : Tensor = onnx::ReduceMean[axes=[-1]](%367)
#   %369 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %370 : FloatTensor = onnx::Add(%368, %369)
#   %371 : Tensor = onnx::Sqrt(%370)
#   %372 : FloatTensor = onnx::Div(%364, %371)
#   %373 : FloatTensor = onnx::Mul(%372, %distilbert.transformer.layer.1.output_layer_norm.weight)
#   %374 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%373, %distilbert.transformer.layer.1.output_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %375 : Tensor = onnx::Shape(%374)
#   %376 : Tensor = onnx::Constant[value={0}]()
#   %377 : Long(device=cpu) = onnx::Gather[axis=0](%375, %376) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:160:0
#   %378 : Tensor = onnx::Shape(%374)
#   %379 : Tensor = onnx::Constant[value={1}]()
#   %380 : Long(device=cpu) = onnx::Gather[axis=0](%378, %379) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:161:0
#   %382 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%374, %893) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %383 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%382, %distilbert.transformer.layer.2.attention.q_lin.bias)
#   %387 : Tensor = onnx::Unsqueeze[axes=[0]](%377)
#   %391 : Tensor = onnx::Concat[axis=0](%387, %894, %895, %896)
#   %392 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%383, %391) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %393 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%392) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %395 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%374, %897) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %396 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%395, %distilbert.transformer.layer.2.attention.k_lin.bias)
#   %400 : Tensor = onnx::Unsqueeze[axes=[0]](%377)
#   %404 : Tensor = onnx::Concat[axis=0](%400, %898, %899, %900)
#   %405 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%396, %404) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %407 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%374, %901) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %408 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%407, %distilbert.transformer.layer.2.attention.v_lin.bias)
#   %412 : Tensor = onnx::Unsqueeze[axes=[0]](%377)
#   %416 : Tensor = onnx::Concat[axis=0](%412, %902, %903, %904)
#   %417 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%408, %416) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %418 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%417) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %419 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={8}]()
#   %420 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Div(%393, %419)
#   %421 : Float(1:6912, 12:64, 64:1, 9:768, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 3, 1]](%405) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %422 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::MatMul(%420, %421) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %423 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %424 : Bool(1:9, 9:1, requires_grad=0, device=cpu) = onnx::Equal(%112, %423) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\tensor.py:27:0
#   %427 : Tensor = onnx::Unsqueeze[axes=[0]](%377)
#   %430 : Tensor = onnx::Unsqueeze[axes=[0]](%380)
#   %431 : Tensor = onnx::Concat[axis=0](%427, %905, %906, %430)
#   %432 : Bool(1:9, 1:9, 1:9, 9:1, requires_grad=0, device=cpu) = onnx::Reshape(%424, %431) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %433 : Tensor = onnx::Shape(%422)
#   %434 : Bool(1:9, 12:0, 9:0, 9:1, requires_grad=0, device=cpu) = onnx::Expand(%432, %433) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %435 : Tensor = onnx::Cast[to=9](%434)
#   %436 : Tensor = onnx::Constant[value={-inf}]()
#   %437 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Where(%435, %436, %422)
#   %438 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Softmax[axis=3](%437) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %439 : Float(1:6912, 12:576, 9:64, 64:1, requires_grad=1, device=cpu) = onnx::MatMul(%438, %418) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:193:0
#   %440 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%439) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %443 : Tensor = onnx::Unsqueeze[axes=[0]](%377)
#   %446 : Tensor = onnx::Concat[axis=0](%443, %907, %908)
#   %447 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Reshape(%440, %446) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %449 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%447, %909) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %450 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%449, %distilbert.transformer.layer.2.attention.out_lin.bias)
#   %451 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%450, %374) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:263:0
#   %453 : Tensor = onnx::ReduceMean[axes=[-1]](%451)
#   %454 : FloatTensor = onnx::Sub(%451, %453)
#   %455 : Tensor = onnx::Cast[to=1](%454)
#   %457 : Tensor = onnx::Pow(%455, %910)
#   %458 : Tensor = onnx::ReduceMean[axes=[-1]](%457)
#   %459 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %460 : FloatTensor = onnx::Add(%458, %459)
#   %461 : Tensor = onnx::Sqrt(%460)
#   %462 : FloatTensor = onnx::Div(%454, %461)
#   %463 : FloatTensor = onnx::Mul(%462, %distilbert.transformer.layer.2.sa_layer_norm.weight)
#   %464 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%463, %distilbert.transformer.layer.2.sa_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %466 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::MatMul(%464, %911) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %467 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Add(%466, %distilbert.transformer.layer.2.ffn.lin1.bias)
#   %468 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.41421}]()
#   %469 : FloatTensor = onnx::Div(%467, %468)
#   %470 : Tensor = onnx::Erf(%469)
#   %471 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %472 : FloatTensor = onnx::Add(%470, %471)
#   %473 : FloatTensor = onnx::Mul(%467, %472)
#   %474 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.5}]()
#   %475 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Mul(%473, %474) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1383:0
#   %477 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%475, %912) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %478 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%477, %distilbert.transformer.layer.2.ffn.lin2.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %479 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%478, %464) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:267:0
#   %481 : Tensor = onnx::ReduceMean[axes=[-1]](%479)
#   %482 : FloatTensor = onnx::Sub(%479, %481)
#   %483 : Tensor = onnx::Cast[to=1](%482)
#   %485 : Tensor = onnx::Pow(%483, %913)
#   %486 : Tensor = onnx::ReduceMean[axes=[-1]](%485)
#   %487 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %488 : FloatTensor = onnx::Add(%486, %487)
#   %489 : Tensor = onnx::Sqrt(%488)
#   %490 : FloatTensor = onnx::Div(%482, %489)
#   %491 : FloatTensor = onnx::Mul(%490, %distilbert.transformer.layer.2.output_layer_norm.weight)
#   %492 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%491, %distilbert.transformer.layer.2.output_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %493 : Tensor = onnx::Shape(%492)
#   %494 : Tensor = onnx::Constant[value={0}]()
#   %495 : Long(device=cpu) = onnx::Gather[axis=0](%493, %494) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:160:0
#   %496 : Tensor = onnx::Shape(%492)
#   %497 : Tensor = onnx::Constant[value={1}]()
#   %498 : Long(device=cpu) = onnx::Gather[axis=0](%496, %497) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:161:0
# ...
#   %656 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Div(%629, %655)
#   %657 : Float(1:6912, 12:64, 64:1, 9:768, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 3, 1]](%641) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %658 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::MatMul(%656, %657) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %659 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %660 : Bool(1:9, 9:1, requires_grad=0, device=cpu) = onnx::Equal(%112, %659) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\tensor.py:27:0
#   %663 : Tensor = onnx::Unsqueeze[axes=[0]](%613)
#   %666 : Tensor = onnx::Unsqueeze[axes=[0]](%616)
#   %667 : Tensor = onnx::Concat[axis=0](%663, %947, %948, %666)
#   %668 : Bool(1:9, 1:9, 1:9, 9:1, requires_grad=0, device=cpu) = onnx::Reshape(%660, %667) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %669 : Tensor = onnx::Shape(%658)
#   %670 : Bool(1:9, 12:0, 9:0, 9:1, requires_grad=0, device=cpu) = onnx::Expand(%668, %669) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %671 : Tensor = onnx::Cast[to=9](%670)
#   %672 : Tensor = onnx::Constant[value={-inf}]()
#   %673 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Where(%671, %672, %658)
#   %674 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Softmax[axis=3](%673) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %675 : Float(1:6912, 12:576, 9:64, 64:1, requires_grad=1, device=cpu) = onnx::MatMul(%674, %654) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:193:0
#   %676 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%675) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %679 : Tensor = onnx::Unsqueeze[axes=[0]](%613)
#   %682 : Tensor = onnx::Concat[axis=0](%679, %949, %950)
#   %683 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Reshape(%676, %682) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %685 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%683, %951) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %686 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%685, %distilbert.transformer.layer.4.attention.out_lin.bias)
#   %687 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%686, %610) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:263:0
#   %689 : Tensor = onnx::ReduceMean[axes=[-1]](%687)
#   %690 : FloatTensor = onnx::Sub(%687, %689)
#   %691 : Tensor = onnx::Cast[to=1](%690)
#   %693 : Tensor = onnx::Pow(%691, %952)
#   %694 : Tensor = onnx::ReduceMean[axes=[-1]](%693)
#   %695 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %696 : FloatTensor = onnx::Add(%694, %695)
#   %697 : Tensor = onnx::Sqrt(%696)
#   %698 : FloatTensor = onnx::Div(%690, %697)
#   %699 : FloatTensor = onnx::Mul(%698, %distilbert.transformer.layer.4.sa_layer_norm.weight)
#   %700 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%699, %distilbert.transformer.layer.4.sa_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %702 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::MatMul(%700, %953) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %703 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Add(%702, %distilbert.transformer.layer.4.ffn.lin1.bias)
#   %704 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.41421}]()
#   %705 : FloatTensor = onnx::Div(%703, %704)
#   %706 : Tensor = onnx::Erf(%705)
#   %707 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %708 : FloatTensor = onnx::Add(%706, %707)
#   %709 : FloatTensor = onnx::Mul(%703, %708)
#   %710 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.5}]()
#   %711 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Mul(%709, %710) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1383:0
#   %713 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%711, %954) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %714 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%713, %distilbert.transformer.layer.4.ffn.lin2.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %715 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%714, %700) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:267:0
#   %717 : Tensor = onnx::ReduceMean[axes=[-1]](%715)
#   %718 : FloatTensor = onnx::Sub(%715, %717)
#   %719 : Tensor = onnx::Cast[to=1](%718)
#   %721 : Tensor = onnx::Pow(%719, %955)
#   %722 : Tensor = onnx::ReduceMean[axes=[-1]](%721)
#   %723 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %724 : FloatTensor = onnx::Add(%722, %723)
#   %725 : Tensor = onnx::Sqrt(%724)
#   %726 : FloatTensor = onnx::Div(%718, %725)
#   %727 : FloatTensor = onnx::Mul(%726, %distilbert.transformer.layer.4.output_layer_norm.weight)
#   %728 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%727, %distilbert.transformer.layer.4.output_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %729 : Tensor = onnx::Shape(%728)
#   %730 : Tensor = onnx::Constant[value={0}]()
#   %731 : Long(device=cpu) = onnx::Gather[axis=0](%729, %730) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:160:0
#   %732 : Tensor = onnx::Shape(%728)
#   %733 : Tensor = onnx::Constant[value={1}]()
#   %734 : Long(device=cpu) = onnx::Gather[axis=0](%732, %733) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:161:0
#   %736 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%728, %956) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %737 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%736, %distilbert.transformer.layer.5.attention.q_lin.bias)
#   %741 : Tensor = onnx::Unsqueeze[axes=[0]](%731)
#   %745 : Tensor = onnx::Concat[axis=0](%741, %957, %958, %959)
#   %746 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%737, %745) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %747 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%746) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %749 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%728, %960) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %750 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%749, %distilbert.transformer.layer.5.attention.k_lin.bias)
#   %754 : Tensor = onnx::Unsqueeze[axes=[0]](%731)
#   %758 : Tensor = onnx::Concat[axis=0](%754, %961, %962, %963)
#   %759 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%750, %758) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %761 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%728, %964) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %762 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%761, %distilbert.transformer.layer.5.attention.v_lin.bias)
#   %766 : Tensor = onnx::Unsqueeze[axes=[0]](%731)
#   %770 : Tensor = onnx::Concat[axis=0](%766, %965, %966, %967)
#   %771 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Reshape(%762, %770) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %772 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%771) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:171:0
#   %773 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={8}]()
#   %774 : Float(1:6912, 12:64, 9:768, 64:1, requires_grad=1, device=cpu) = onnx::Div(%747, %773)
#   %775 : Float(1:6912, 12:64, 64:1, 9:768, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 3, 1]](%759) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %776 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::MatMul(%774, %775) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:182:0
#   %777 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %778 : Bool(1:9, 9:1, requires_grad=0, device=cpu) = onnx::Equal(%112, %777) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\tensor.py:27:0
#   %781 : Tensor = onnx::Unsqueeze[axes=[0]](%731)
#   %784 : Tensor = onnx::Unsqueeze[axes=[0]](%734)
#   %785 : Tensor = onnx::Concat[axis=0](%781, %968, %969, %784)
#   %786 : Bool(1:9, 1:9, 1:9, 9:1, requires_grad=0, device=cpu) = onnx::Reshape(%778, %785) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %787 : Tensor = onnx::Shape(%776)
#   %788 : Bool(1:9, 12:0, 9:0, 9:1, requires_grad=0, device=cpu) = onnx::Expand(%786, %787) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:183:0
#   %789 : Tensor = onnx::Cast[to=9](%788)
#   %790 : Tensor = onnx::Constant[value={-inf}]()
#   %791 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Where(%789, %790, %776)
#   %792 : Float(1:972, 12:81, 9:9, 9:1, requires_grad=1, device=cpu) = onnx::Softmax[axis=3](%791) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %793 : Float(1:6912, 12:576, 9:64, 64:1, requires_grad=1, device=cpu) = onnx::MatMul(%792, %772) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:193:0
#   %794 : Float(1:6912, 9:768, 12:64, 64:1, requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3]](%793) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %797 : Tensor = onnx::Unsqueeze[axes=[0]](%731)
#   %800 : Tensor = onnx::Concat[axis=0](%797, %970, %971)
#   %801 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Reshape(%794, %800) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:175:0
#   %803 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%801, %972) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %804 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%803, %distilbert.transformer.layer.5.attention.out_lin.bias)
#   %805 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%804, %728) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:263:0
#   %807 : Tensor = onnx::ReduceMean[axes=[-1]](%805)
#   %808 : FloatTensor = onnx::Sub(%805, %807)
#   %809 : Tensor = onnx::Cast[to=1](%808)
#   %811 : Tensor = onnx::Pow(%809, %973)
#   %812 : Tensor = onnx::ReduceMean[axes=[-1]](%811)
#   %813 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %814 : FloatTensor = onnx::Add(%812, %813)
#   %815 : Tensor = onnx::Sqrt(%814)
#   %816 : FloatTensor = onnx::Div(%808, %815)
#   %817 : FloatTensor = onnx::Mul(%816, %distilbert.transformer.layer.5.sa_layer_norm.weight)
#   %818 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%817, %distilbert.transformer.layer.5.sa_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:2095:0
#   %820 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::MatMul(%818, %974) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %821 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Add(%820, %distilbert.transformer.layer.5.ffn.lin1.bias)
#   %822 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.41421}]()
#   %823 : FloatTensor = onnx::Div(%821, %822)
#   %824 : Tensor = onnx::Erf(%823)
#   %825 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %826 : FloatTensor = onnx::Add(%824, %825)
#   %827 : FloatTensor = onnx::Mul(%821, %826)
#   %828 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.5}]()
#   %829 : Float(1:27648, 9:3072, 3072:1, requires_grad=1, device=cpu) = onnx::Mul(%827, %828) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1383:0
#   %831 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::MatMul(%829, %975) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %832 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%831, %distilbert.transformer.layer.5.ffn.lin2.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %833 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%832, %818) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:267:0
#   %835 : Tensor = onnx::ReduceMean[axes=[-1]](%833)
#   %836 : FloatTensor = onnx::Sub(%833, %835)
#   %837 : Tensor = onnx::Cast[to=1](%836)
#   %839 : Tensor = onnx::Pow(%837, %976)
#   %840 : Tensor = onnx::ReduceMean[axes=[-1]](%839)
#   %841 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1e-12}]()
#   %842 : FloatTensor = onnx::Add(%840, %841)
#   %843 : Tensor = onnx::Sqrt(%842)
#   %844 : FloatTensor = onnx::Div(%836, %843)
#   %845 : FloatTensor = onnx::Mul(%844, %distilbert.transformer.layer.5.output_layer_norm.weight)
#   %846 : Float(1:6912, 9:768, 768:1, requires_grad=1, device=cpu) = onnx::Add(%845, %distilbert.transformer.layer.5.output_layer_norm.bias) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:983:0
#   %848 : Float(1:189, 9:21, 21:1, requires_grad=1, device=cpu) = onnx::MatMul(%846, %977) # C:\Users\chiecha.REDMOND\Miniconda3\envs\azureml\lib\site-packages\torch\nn\functional.py:1692:0
#   %logits : Float(1:189, 9:21, 21:1, requires_grad=1, device=cpu) = onnx::Add(%848, %classifier.bias)
#   return (%logits)
