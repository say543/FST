# %%
import azureml.core
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.15.0

# %%
from azureml.core import Workspace



#old account in blob
subscription_id = "ddb33dc4-889c-4fa1-90ce-482d793d6480"
resource_group = "DevExp"
workspace_name = "DevExperimentation"






try:
    #print('1')
    ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
    #print('2')
    ws.write_config()
    print('Library configuration succeeded')
    print(ws.get_details()['id'])

    print('https://ms.portal.azure.com/#@microsoft.onmicrosoft.com/resource' + ws.get_details()['id'])
except:
    print('Workspace not found')
# Out:
# Library configuration succeeded
# /subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation
# https://ms.portal.azure.com/#@microsoft.onmicrosoft.com/resource/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation

# %%
#resource group in email inference
{
    "subscription_id": "58f08321-00aa-4ada-bd53-421ecd063782",
    "resource_group": "Compliant_LU",
    "workspace_name": "Teams_ws"
}
# Out:
# {'subscription_id': '58f08321-00aa-4ada-bd53-421ecd063782',
#  'resource_group': 'Compliant_LU',
#  'workspace_name': 'Teams_ws'}

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

#old gpu  8 nodes
cluster_name = "P100-DualGPU"

# seems ok for 8 node
#cluster_name = "P100-QuadGPU"

# only 4 nodes 
#cluster_name = "V100-QuadGPU"


try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
# Out:
# Found existing compute target.

# %%
ds = ws.get_default_datastore()

# %%
from azureml.core import Datastore
ds = Datastore.get(ws, 'chiecha_datastore')

# %%
#$AZUREML_DATAREFERENCE_e2b58eeb943a48968b3f9e7c5c7a9925
#reference can be used in python module(?? not sure, check in the future) 

#upload local model
##model_path_on_datastore = 'Teams_slot_model' #cased model,vocab is too small? Do not have frequent word like common
##ds_model = ds.path(model_path_on_datastore)
##ds.upload(src_dir=r'D:\dl_repo\Tagging_data\bert-base-English-cased-pytorch',
##          target_path= model_path_on_datastore,
##          overwrite=False,
##          show_progress=True)
##print(ds_model.as_mount())

#upload unsupervised local model
##model_path_on_datastore = 'Communication_slot_model_unsupervised' #cased model,vocab is too small? Do not have frequent word like common
##ds_model_unsupervised = ds.path(model_path_on_datastore)
##ds.upload(src_dir=r'D:\dl_repo\Data_model\Communication_unsupervised',
##          target_path= model_path_on_datastore,
##          overwrite=False,
##          show_progress=True)
##print(ds_model_unsupervised.as_mount())

#upload local data set
##path_on_datastore = 'datasets/Teams_communication'
##ds_data_communication = ds.path(path_on_datastore)
##ds.upload(src_dir=r'D:\dl_repo\Data_model\Communication_data',
##          target_path= path_on_datastore,
##          overwrite=False,
##          show_progress=True)

# files training data source
#path_on_datastore = 'resource/Data'
#ds_data_files = ds.path(path_on_datastore)
#ds.upload(src_dir=r'E:\fileAnswer_data_synthesis\CMF_training\resource\Data',
#          target_path= path_on_datastore,
#          overwrite=False,
#          show_progress=True)

# git data source for normal domain training
#path_on_datastore = 'resource/Data'
#ds_data_files = ds.path(path_on_datastore)

#ds.upload(src_dir=r'E:\CoreScienceDataStaging\datasources\Files\resource\Data',
#          target_path= path_on_datastore,
#          overwrite=False,
#          show_progress=True)


# local data source for normal domain training

path_on_datastore = './azureml_data'
ds_data_files = ds.path(path_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\azureml_data',
          target_path= path_on_datastore,
          overwrite=True,
          show_progress=True)


# 

# training script

training_script_on_datastore = './training_script'
ds_data_files = ds.path(training_script_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\training_script',
          target_path= training_script_on_datastore,
          overwrite=True,
          show_progress=True)



#TNLR model
'''
TNLR_on_datastore = './TNLR'
ds_data_files = ds.path(TNLR_on_datastore)
ds.upload(src_dir=r'E:\azure_ml_notebook\TNLR',
          target_path= TNLR_on_datastore,
          overwrite=True,
          show_progress=True)
'''
# Out:
# Uploading an estimated of 48 files
# Uploading E:\azure_ml_notebook\azureml_data\after_my_preprocessingOriginalSlotIdsv1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\after_my_preprocessingOriginalSlotIdsv1.tsv, 1 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_test_problematic_queires.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_test_problematic_queires.tsv, 2 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_train_ten.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_train_ten.tsv, 3 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer_small.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer_small.tsv, 4 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_single.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_single.tsv, 5 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_small.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_small.tsv, 6 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_double_fake_annotation_01202021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_double_fake_annotation_01202021v1.tsv, 7 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_ten_01202021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_ten_01202021v1.tsv, 8 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_test.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_test.tsv, 9 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_test_backup.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_test_backup.tsv, 10 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\complaints_after.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\complaints_after.tsv, 11 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\complaints_after_backup.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\complaints_after_backup.tsv, 12 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\complaints_sampled_after.csv
# Uploaded E:\azure_ml_notebook\azureml_data\complaints_sampled_after.csv, 13 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer_single.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer_single.tsv, 14 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_small - Copy.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_small - Copy.tsv, 15 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_ten.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_ten.tsv, 16 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\filter_query_for_domain.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\filter_query_for_domain.tsv, 17 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\open_ppt_augmentation.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\open_ppt_augmentation.tsv, 18 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\open_ppt_augmentation_02272021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\open_ppt_augmentation_02272021v1.tsv, 19 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_train.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_train.tsv, 20 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_train.tsv_after_my_preprocessing.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_train.tsv_after_my_preprocessing.tsv, 21 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_train_02112021v_backup1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_train_02112021v_backup1.tsv, 22 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TestSet_backup_original_02182021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TestSet_backup_original_02182021v1.tsv, 23 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\slot_wrong_format.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\slot_wrong_format.tsv, 24 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_train.tsv_after_my_preprocessing_before_v1_apply_02132021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_train.tsv_after_my_preprocessing_before_v1_apply_02132021v1.tsv, 25 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TestSet.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TestSet.tsv, 26 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_small_01202021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_small_01202021v1.tsv, 27 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\atis_train_first_query_test_tokenizer.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\atis_train_first_query_test_tokenizer.tsv, 28 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_domain_training_answer_updated_small.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_domain_training_answer_updated_small.tsv, 29 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\dev_bert_files_slot.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\dev_bert_files_slot.tsv, 30 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_problematic_data.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_problematic_data.tsv, 31 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_02032021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_02032021v1.tsv, 32 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_before_combine.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_before_combine.tsv, 33 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_train_after_my_preprocessing_02062021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_train_after_my_preprocessing_02062021v1.tsv, 34 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training.tsv, 35 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_02062021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_02062021v1.tsv, 36 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_train_after_my_preprocessing.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_train_after_my_preprocessing.tsv, 37 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1_after_my_preprocessing.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1_after_my_preprocessing.tsv, 38 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\train_bert_files_slot.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\train_bert_files_slot.tsv, 39 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_slot_training_01282021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_slot_training_01282021v1.tsv, 40 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_domain_training_answer.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_domain_training_answer.tsv, 41 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_domain_training_answer_updated.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_domain_training_answer_updated.tsv, 42 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1_02272021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1_02272021v1.tsv, 43 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer_old.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer_old.tsv, 44 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1.tsv, 45 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\files_domain_training_contexual_answer.tsv, 46 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1 - Copy.tsv
# Uploaded E:\azure_ml_notebook\azureml_data\MDM_TrainSet_01202021v1 - Copy.tsv, 47 files out of an estimated total of 48
# Uploading E:\azure_ml_notebook\azureml_data\complaints.csv
# Uploaded E:\azure_ml_notebook\azureml_data\complaints.csv, 48 files out of an estimated total of 48
# Uploaded 48 files
# Uploading an estimated of 113 files
# Uploading E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_02152021v1.py
# WARNING - Retrying (Retry(total=2, connect=3, read=2, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(10054, 'WSAECONNRESET')",))': /chiecha/training_script%5Catis_train_horovod_joint_intent_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_02152021v1.py, 1 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR.py, 2 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_02162021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_02162021v1.py, 3 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_bfore_change_to_load_onnx_model_02142021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_bfore_change_to_load_onnx_model_02142021v1.py, 4 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_enable_distributed_sampler.py
# Uploaded E:\azure_ml_notebook\training_script\atis_model_saved_test_joint_intent_slot_TNLR_enable_distributed_sampler.py, 5 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_slot_to_label_id_success.py
# Uploaded E:\azure_ml_notebook\training_script\atis_slot_to_label_id_success.py, 6 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_slot_to_label_id_success_02122021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_slot_to_label_id_success_02122021v1.py, 7 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_slot_to_label_id_success_02132021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_slot_to_label_id_success_02132021v1.py, 8 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR.py, 9 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_02152021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_02152021v1.py, 10 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_02162021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_02162021v1.py, 11 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_02172021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_02172021v1.py, 12 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_activate_distributed_sampler_02172021v1.py.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_activate_distributed_sampler_02172021v1.py.py, 13 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_before_minic_atis_git_02122021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_before_minic_atis_git_02122021v1.py, 14 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local - Copy.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local - Copy.py, 15 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local.py, 16 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local_before_mimic_atis_git_02122021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local_before_mimic_atis_git_02122021v1.py, 17 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_temp_02152021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_temp_02152021v1.py, 18 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\basic_onnx_test.py
# Uploaded E:\azure_ml_notebook\training_script\basic_onnx_test.py, 19 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\chunk_forward_test.py
# Uploaded E:\azure_ml_notebook\training_script\chunk_forward_test.py, 20 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02182021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02182021v1.py, 21 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02242021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02242021v1.py, 22 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02282021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02282021v1.py, 23 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02162021v2.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02162021v2.py, 24 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02262021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02262021v1.py, 25 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02272021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02272021v1.py, 26 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02282021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02282021v1.py, 27 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_before_remove_useless_code_02262021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_before_remove_useless_code_02262021v1.py, 28 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_for_review.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_for_review.py, 29 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_local.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_local.py, 30 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_local_02142021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_local_02142021v1.py, 31 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_12312020v1.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_12312020v1.py, 32 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR.py, 33 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR_01272021v1.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR_01272021v1.py, 34 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR_01302021v1.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR_01302021v1.py, 35 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR_02022021v1.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_joint_intent_slot_TNLR_02022021v1.py, 36 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot.py, 37 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot_12302020v1.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot_12302020v1.py, 38 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot_12302020v2.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot_12302020v2.py, 39 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot_12302020v3.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot_12302020v3.py, 40 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR.py, 41 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR_01142021v1.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR_01142021v1.py, 42 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\preprocess_bert.py
# Uploaded E:\azure_ml_notebook\training_script\preprocess_bert.py, 43 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test_02122021v1.py
# Uploaded E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test_02122021v1.py, 44 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test_backup_distill_tokenizerFast.py
# Uploaded E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test_backup_distill_tokenizerFast.py, 45 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test_backup_fastokenizer_non_finished - Copy.py
# Uploaded E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test_backup_fastokenizer_non_finished - Copy.py, 46 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod.py, 47 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_1216_2020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_1216_2020v1.py, 48 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_backup.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_backup.py, 49 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_before_add_comment_10072020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_before_add_comment_10072020v1.py, 50 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\hugging_face_load.py
# Uploaded E:\azure_ml_notebook\training_script\hugging_face_load.py, 51 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR.py, 52 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02172021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02172021v1.py, 53 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test.py, 54 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR_01152021v2.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR_01152021v2.py, 55 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\slot_data_debug.py
# Uploaded E:\azure_ml_notebook\training_script\slot_data_debug.py, 56 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_12212020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_12212020v1.py, 57 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR.py, 58 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_02022021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_02022021v1.py, 59 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_02062021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_02062021v1.py, 60 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local.py, 61 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_01272021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_01272021v1.py, 62 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_01302021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_01302021v1.py, 63 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_02042021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_02042021v1.py, 64 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_02062021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_02062021v1.py, 65 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_02062021v2.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_02062021v2.py, 66 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_before_minic_atis_local.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_before_minic_atis_local.py, 67 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_five_output_but_still_faile_onnx_02022021v2.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_five_output_but_still_faile_onnx_02022021v2.py, 68 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_useseqeval_but_format_is_restrict_02052021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_local_useseqeval_but_format_is_restrict_02052021v1.py, 69 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_three_output_ok_backup_02022021v3.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_joint_intent_slot_TNLR_three_output_ok_backup_02022021v3.py, 70 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_local.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_local.py, 71 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_local_12172020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_local_12172020v1.py, 72 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_non_contexual_domain.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_non_contexual_domain.py, 73 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_non_contexual_domain_01022020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_non_contexual_domain_01022020v1.py, 74 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot.py, 75 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_01072021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_01072021v1.py, 76 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_01082021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_01082021v1.py, 77 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_01122021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_01122021v1.py, 78 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_12262020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_12262020v1.py, 79 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_12292020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_12292020v1.py, 80 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v1.py, 81 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v2.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v2.py, 82 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v3.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v3.py, 83 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v4.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_12302020v4.py, 84 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_local.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_local.py, 85 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_overloaed_class_with_label_outout_success_12312020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_overloaed_class_with_label_outout_success_12312020v1.py, 86 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR.py, 87 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_01142020v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_01142020v1.py, 88 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_local.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_local.py, 89 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_local_01152021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_local_01152021v1.py, 90 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_local_02022021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_TNLR_local_02022021v1.py, 91 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success.py, 92 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01072021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01072021v1.py, 93 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01082021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01082021v1.py, 94 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01082021v2.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01082021v2.py, 95 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01082021v3.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_01082021v3.py, 96 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_02122021v1.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_to_label_id_success_02122021v1.py, 97 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_slot_using_yue_class_01082020v4.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_slot_using_yue_class_01082020v4.py, 98 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\train_horovod_with_class.py
# Uploaded E:\azure_ml_notebook\training_script\train_horovod_with_class.py, 99 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\__pycache__\preprocess_bert.cpython-36.pyc
# Uploaded E:\azure_ml_notebook\training_script\__pycache__\preprocess_bert.cpython-36.pyc, 100 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local_before_add_self_load_function_02142021v1.py
# Uploaded E:\azure_ml_notebook\training_script\atis_train_horovod_joint_intent_slot_TNLR_local_before_add_self_load_function_02142021v1.py, 101 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02192021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02192021v1.py, 102 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02212021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02212021v1.py, 103 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02272021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_model_saved_test_joint_intent_slot_TNLR_02272021v1.py, 104 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_slot_to_label_id_success.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_slot_to_label_id_success.py, 105 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_DistillBert.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_DistillBert.py, 106 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR.py, 107 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02162021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02162021v1.py, 108 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02202021v1.py
# Uploaded E:\azure_ml_notebook\training_script\MDM_train_horovod_joint_intent_slot_TNLR_02202021v1.py, 109 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot - Copy.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot - Copy.py, 110 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR_01152021v1.py
# Uploaded E:\azure_ml_notebook\training_script\model_saved_test_slot_TNLR_01152021v1.py, 111 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\preprocess_bert_02122021v1.py
# Uploaded E:\azure_ml_notebook\training_script\preprocess_bert_02122021v1.py, 112 files out of an estimated total of 113
# Uploading E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test.py
# Uploaded E:\azure_ml_notebook\training_script\slot_label_bert_preprocess_test.py, 113 files out of an estimated total of 113
# Uploaded 113 files
# "\nTNLR_on_datastore = './TNLR'\nds_data_files = ds.path(TNLR_on_datastore)\nds.upload(src_dir=r'E:\x07zure_ml_notebook\\TNLR',\n          target_path= TNLR_on_datastore,\n          overwrite=True,\n          show_progress=True)\n"

# %%
# minic and create an domain training experiemnt
from azureml.core import Experiment

# test different experiment name
experiment_name = 'MDM_joint_intent_slot_classification_using_TNLRv3' 
experiment = Experiment(ws, name=experiment_name)

# %% [markdown]
# ## Create a PyTorch estimator
# The AML SDK's PyTorch estimator enables you to easily submit PyTorch training jobs for both single-node and distributed runs. For more information on the PyTorch estimator, refer here. The following code will define a single-node PyTorch job.

# %%
##BATCH AI
from azureml.train.dnn import PyTorch



### for debug if data is reable
from azureml.core import Dataset



training_datastore_path = [(ds, './azureml_data/MDM_TrainSet_01202021v1.tsv')]

training_dataset_obj = Dataset.File.from_files(path=training_datastore_path)

training_dataset_name = 'training_non_contexual_slot_data_set'
training_dataset_description = 'training_non_contexual_slot_data_set description'


training_dataset = training_dataset_obj.register(workspace=ws, name=training_dataset_name, description=training_dataset_description, create_new_version=True)


# augmented data test 
augmented_datastore_path = [(ds, './azureml_data/open_ppt_augmentation.tsv')]

augmented_dataset_obj = Dataset.File.from_files(path=augmented_datastore_path)

augmented_dataset_name = 'augmented_non_contexual_slot_data_set'
augmented_dataset_description = 'augmented_non_contexual_slot_data_set description'


augmented_dataset = augmented_dataset_obj.register(workspace=ws, name=augmented_dataset_name, description=augmented_dataset_description, create_new_version=True)



#TNLR model
TNLRv3_path = [(ds, './TNLR/tnlrv3-base.pt')]

TNLRv3_obj = Dataset.File.from_files(path=TNLRv3_path)

TNLRv3_name = 'TNLRv3_pretrained_model'
TNLRv3_description = 'TNLRv3_pretrained_model description'

TNLRv3_model = TNLRv3_obj.register(workspace=ws, name=TNLRv3_name, description=TNLRv3_description, create_new_version=True)



# for debug new format
import pandas as pd
file_name = training_dataset.download()[0]
df = pd.read_csv(file_name, sep='\t', encoding="utf-8")
print(df.head())





from azureml.core.runconfig import MpiConfiguration
from azureml.train.hyperdrive import GridParameterSampling
from azureml.train.hyperdrive import HyperDriveConfig
from azureml.train.hyperdrive import PrimaryMetricGoal
from azureml.train.hyperdrive.parameter_expressions import choice


script_folder = './training_script'



# new dataset name
script_params = {
    #'--dataset_name': 'training_data_set'
    '--dataset_name': 'training_non_contexual_slot_data_set',
    #augment dataset name
    '--augment_dataset_name': 'augmented_non_contexual_slot_data_set',
    '--TNLR_model_bin': 'TNLRv3_model',
    #'--pretrain_model': 'distilbert-base-uncased'
    #'--pretrain_model': 'bert-base-uncased'
    #'--pretrain_model': 'distilbert-base-uncased'
}



estimator = PyTorch(source_directory = script_folder,
                    compute_target = compute_target,
                    entry_script = 'MDM_train_horovod_joint_intent_slot_TNLR.py',
                    script_params = script_params,
                    use_gpu = True,
                    node_count=8,
                    process_count_per_node=1,
                    distributed_training=MpiConfiguration(),
                    # setup transformers package number
                    #pip_packages = ['sklearn', 'joblib', 'transformers', 'azureml-dataprep[fuse,pandas]'])
                    pip_packages = ['sklearn', 'joblib', 'transformers==4.1.1', 'azureml-dataprep[fuse,pandas]', 'seqeval'])


#ve
param_sampling = GridParameterSampling({
    'batch_size': choice(32),
    # originla learning rate
    #'learning_rate': choice(1e-5),
    # change to bigger learning rate
    #'learning_rate': choice(5e-5),
    # combined tow at the same time
    'learning_rate': choice(5e-5, 1e-5),
    'adam_epsilon': choice(1e-8),
    'seed_val': choice(111),
    # add epoch parameter
    #'num_epochs': choice(1)})
    #'num_epochs': choice(5)})
    #'num_epochs': choice(25)})
    'num_epochs': choice(10)})
    #'num_epochs': choice(5,10)})
    #'num_epochs': choice(5,10,15)})
    #'num_epochs': choice(15,20,25)})
    #'num_epochs': choice(5,10,15,20,25)})



#horovod
#https://docs.microsoft.com/en-us/azure/machine-learning/how-to-train-pytorch
hyperdrive_run_config = HyperDriveConfig(estimator = estimator,
                                         hyperparameter_sampling = param_sampling,
                                         policy = None,
                                         primary_metric_name = 'validation loss',
                                         primary_metric_goal = PrimaryMetricGoal.MINIMIZE,
                                         # increase to 3 to see different validation through graph
                                         # ? but graph still only outputs one point
                                         #max_total_runs = 1,
                                         max_total_runs = 5,
                                         max_concurrent_runs = 1)


#hyperdrive_run = exp.submit(hyperdrive_run_config)
hyperdrive_run = experiment.submit(hyperdrive_run_config)
# show detail
from azureml.widgets import RunDetails
RunDetails(hyperdrive_run).show()


# this is to show metric so comment it at first

hyperdrive_run.wait_for_completion(show_output = False)

children = list(hyperdrive_run.get_children())
metricslist = {}
i = 0

for single_run in children:
    results = {k: v for k, v in single_run.get_metrics().items() if isinstance(v, float)}
    parameters = single_run.get_details()['runDefinition']['arguments']
    try:
        results['batch_size'] = parameters[3]
        results['learning_rate'] = parameters[5]
        results['adam_epsilon'] = parameters[7]
        results['num_epochs'] = parameters[9]
        metricslist[i] = results
        i += 1
    except:
        pass

rundata = pd.DataFrame(metricslist).sort_index(1).T.sort_values(by = ['validation loss'], ascending = True)
rundata
# Out:
# WARNING - framework_version is not specified, defaulting to version 1.4.
# WARNING - If 'script' has been provided here and a script file name has been specified in 'run_config', 'script' provided in ScriptRunConfig initialization will take precedence.
# WARNING - If 'arguments' has been provided here and arguments have been specified in 'run_config', 'arguments' provided in ScriptRunConfig initialization will take precedence.
#   ConversationId  MessageId MessageTimestamp MessageFrom          MessageText  \
# 0        BVT-456        0.0              NaN        user        Cancel my 4pm
# 1        BVT-457        0.0              NaN        user  Cancel my 7 o'clock
# 2        BVT-460        0.0              NaN        user       Remove my 10am
# 3        BVT-461        0.0              NaN        user  Remove my 1 o'clock
# 4        BVT-464        0.0              NaN        user      Decline my 11am
#
#   JudgedDomain           JudgedIntent  \
# 0     calendar  delete_calendar_entry
# 1     calendar  delete_calendar_entry
# 2     calendar  delete_calendar_entry
# 3     calendar  delete_calendar_entry
# 4     calendar  delete_calendar_entry
#
#                               JudgedConstraints ConversationContext MetaData  \
# 0        Cancel my <start_time>4pm</start_time>                 NaN       []
# 1  Cancel my <start_time>7</start_time> o'clock                 NaN       []
# 2       Remove my <start_time>10am</start_time>                 NaN       []
# 3  Remove my <start_time>1</start_time> o'clock                 NaN       []
# 4      Decline my <start_time>11am</start_time>                 NaN       []
#
#    ...  SelectionIgnore MultiAnnotationFlag MaxAnnotations  \
# 0  ...              NaN                 NaN            NaN
# 1  ...              NaN                 NaN            NaN
# 2  ...              NaN                 NaN            NaN
# 3  ...              NaN                 NaN            NaN
# 4  ...              NaN                 NaN            NaN
#
#   MultiAnnotationType InputMethod  MultiturnIgnore  RuleTreeNBestList  \
# 0                 NaN         NaN              NaN                NaN
# 1                 NaN         NaN              NaN                NaN
# 2                 NaN         NaN              NaN                NaN
# 3                 NaN         NaN              NaN                NaN
# 4                 NaN         NaN              NaN                NaN
#
#    ImplicitConstraints Dataset.1  SampleType.1
# 0                  NaN       NaN           NaN
# 1                  NaN       NaN           NaN
# 2                  NaN       NaN           NaN
# 3                  NaN       NaN           NaN
# 4                  NaN       NaN           NaN
#
# [5 rows x 29 columns]
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0276C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0276C88>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0276C18>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B05E10F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B05E1B70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B07960B8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B07AB828>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0A1BCC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0A1B5F8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0A58C18>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0A585F8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0A580F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0C5A5C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0CFBA20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0CFB9E8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0E30C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0E30BA8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
# WARNING - Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002F0B0E30550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',)': /history/v1.0/subscriptions/ddb33dc4-889c-4fa1-90ce-482d793d6480/resourceGroups/DevExp/providers/Microsoft.MachineLearningServices/workspaces/DevExperimentation/experiments/MDM_joint_intent_slot_classification_using_TNLRv3/runs/HD_ce4ceb5c-6c18-452b-993f-0231572a4393
